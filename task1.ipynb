# %%
import pandas as pd

# %%
df = pd.read_csv(r"/content/student_performance_cleaned.csv")

# %% [markdown]
# by using head i printed the 1st 10 values

# %%
print(df.head(10))
# Out:
#   studentid      name  gender  attendancerate  studyhoursperweek  \
# 0       1.0      John    Male            85.0               15.0
# 1       2.0     Sarah  Female            90.0               20.0
# 2       3.0      Alex    Male            78.0               10.0
# 3       4.0   Michael    Male            92.0               25.0
# 4       5.0      Emma  Female            88.0               18.0
# 5       6.0    Olivia  Female            95.0               30.0
# 6       7.0    Daniel    Male            70.0                8.0
# 7       8.0    Sophia  Female            88.0               17.0
# 8       9.0     James    Male            82.0               12.0
# 9      10.0  Isabella  Female            91.0               22.0
#
#    previousgrade  extracurricularactivities parentalsupport finalgrade  \
# 0           78.0                        1.0            High       80.0
# 1           85.0                        2.0          Medium       87.0
# ...

# %% [markdown]
# dataset information

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   studentid                  990 non-null    object
#  1   name                       990 non-null    object
#  2   gender                     990 non-null    object
#  3   attendancerate             990 non-null    float64
#  4   studyhoursperweek          990 non-null    float64
#  5   previousgrade              990 non-null    float64
#  6   extracurricularactivities  990 non-null    float64
#  7   parentalsupport            990 non-null    object
#  8   finalgrade                 990 non-null    object
#  9   study_hours                990 non-null    float64
#  10  attendance_(%)             990 non-null    float64
#  11  online_classes_taken       990 non-null    bool
# dtypes: bool(1), float64(6), object(5)
# memory usage: 86.2+ KB
# None

# %% [markdown]
# columns names

# %%
print(df.columns)
# Out:
# Index(['studentid', 'name', 'gender', 'attendancerate', 'studyhoursperweek',
#        'previousgrade', 'extracurricularactivities', 'parentalsupport',
#        'finalgrade', 'study_hours', 'attendance_(%)', 'online_classes_taken'],
#       dtype='object')

# %% [markdown]
# for finding null values

# %%
print("null value :",df.isnull().sum())
# Out:
# null value : studentid                    0
# name                         0
# gender                       0
# attendancerate               0
# studyhoursperweek            0
# previousgrade                0
# extracurricularactivities    0
# parentalsupport              0
# finalgrade                   0
# study_hours                  0
# attendance_(%)               0
# online_classes_taken         0
# dtype: int64

# %% [markdown]
# for finding duplicate records

# %%
print("duplicated :",df.duplicated().sum)
# Out:
# duplicated : <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# Length: 990, dtype: bool>

# %% [markdown]
# check data type

# %%
print(df.dtypes)
# Out:
# studentid                     object
# name                          object
# gender                        object
# attendancerate               float64
# studyhoursperweek            float64
# previousgrade                float64
# extracurricularactivities    float64
# parentalsupport               object
# finalgrade                    object
# study_hours                  float64
# attendance_(%)               float64
# online_classes_taken            bool
# dtype: object

# %% [markdown]
# Remove Duplicate Records

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Handle Missing Values

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %% [markdown]
# removing extra spaces

# %%
df.columns = df.columns.str.strip()

for col in df.select_dtypes(include="object"):
    df[col] = df[col].str.strip()

# %% [markdown]
# checking data again

# %%
df.isnull().sum()
# Out:
# studentid                    0
# name                         0
# gender                       0
# attendancerate               0
# studyhoursperweek            0
# previousgrade                0
# extracurricularactivities    0
# parentalsupport              0
# finalgrade                   0
# study_hours                  0
# attendance_(%)               0
# online_classes_taken         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   studentid                  990 non-null    object
#  1   name                       990 non-null    object
#  2   gender                     990 non-null    object
#  3   attendancerate             990 non-null    float64
#  4   studyhoursperweek          990 non-null    float64
#  5   previousgrade              990 non-null    float64
#  6   extracurricularactivities  990 non-null    float64
#  7   parentalsupport            990 non-null    object
#  8   finalgrade                 990 non-null    object
#  9   study_hours                990 non-null    float64
#  10  attendance_(%)             990 non-null    float64
#  11  online_classes_taken       990 non-null    bool
# dtypes: bool(1), float64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# for saving

# %%
# Save the cleaned dataset as a new CSV file
df.to_csv("student_performance_final.csv", index=False)

print("Cleaned dataset saved successfully as 'student_performance_final.csv'")
# Out:
# Cleaned dataset saved successfully as 'student_performance_final.csv'
